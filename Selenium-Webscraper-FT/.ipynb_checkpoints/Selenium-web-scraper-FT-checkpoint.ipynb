# %%
# -------------------- Imports -------------------- #
import time
import pandas as pd
import json

from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# -------------------- Variables -------------------- #

TARGET_URL = 'https://www.ft.com/technology'
CHROME_DRIVER_PATH = r"C:\Users\miran\Desktop\GitHub\WEB-DRIVERS\chromedriver.exe"
NUMBER_OF_PAGES = 100

driver = None

# %%
# -------------------- Driver Configuration -------------------- #
try:
    driver = webdriver.Chrome(CHROME_DRIVER_PATH)
    driver.get(TARGET_URL)
    driver.maximize_window()
    driver.implicitly_wait(10)
    print('Configuration successful. Website loaded')
except:
    print('configuration failed!')
# Out:
# Configuration successful. Website loaded

# %%
# -------------------- Accepting Cookies -------------------- #
try:
    driver.find_element_by_class_name('o-cookie-message__button').click()
    print('Cookies accepted successfully.')
except:
    print('Cookies are not accepted')
# Out:
# Cookies accepted successfully.

# %%
# $x('//li[@class="o-teaser-collection__item o-grid-row"]//a[@class="o-teaser__tag"]'); PUBLISHER
# $x('//li[@class="o-teaser-collection__item o-grid-row"]//a[@class="js-teaser-heading-link"]'); TITLES
# $x('//li[@class="o-teaser-collection__item o-grid-row"]//a[@class="js-teaser-standfirst-link"]'); CONTENT

# XPATH I used
# $x('//li[@class="o-teaser-collection__item o-grid-row"]//*[@class="o-teaser__content"]'); FOR CONTAINER WHICH CONTAINS: Publisher, Title, Content describtion
# $x('//li[@class="o-teaser-collection__item o-grid-row"]//time[@class="o-date"]'); DATES

# %%
# -------------------- start timer -------------------- #
startTime = time.time()

# %%
# -------------------- WEB SCRAPER VARIABLES -------------------- #
dates = []
publishers = []
titles = []
content = []

# %%
# container = driver.find_elements_by_xpath('//li[@class="o-teaser-collection__item o-grid-row"]//*[@class="o-teaser__content"]')
# frontier = container[0].text.split('\n')
# frontier.pop() # last element is "save" bookmark. So it is not really useful.
# if ' content' in frontier:
#     frontier.remove(' content')
# print(frontier)

# %%
# -------------------- WEB SCRAPER -------------------- #

try:
    
    for page in range(NUMBER_OF_PAGES):

        # finds content using XPATH
        container = driver.find_elements_by_xpath('//li[@class="o-teaser-collection__item o-grid-row"]//*[@class="o-teaser__content"]') # CONTAINS: Publisher, Title, Content describtion
        dates_container = driver.find_elements_by_xpath('//li[@class="o-teaser-collection__item o-grid-row"]//time[@class="o-date"]') # CONTAINS: Dates

        # takes every element from container and adds it to a frontier where the text splits into sections: Publisher, Title, Content. Adding each element to respected array.
        for i in range(len(container)):
            frontier = container[i].text.split('\n')
            frontier.pop() # last element is "save" bookmark. So it is not really useful.
            if ' content' in frontier:
                frontier.remove(' content')
            # print(frontier)
            
            if len(frontier) == 4:
                frontier.pop()
            
            if len(frontier) == 3:
                publishers.append(frontier[0])
                titles.append(frontier[1])
                content.append(frontier[2])
            
            # it catches the news articles with no content describtion
            elif len(frontier) == 2:
                publishers.append(frontier[0])
                titles.append(frontier[1])
                content.append('NO CONTENT')
        
        # parsing dates and adding them to separate array
        for date in dates_container:
            dates.append(date.text)

        # fixing empty date slots (taking into consideration specification of the website)
        for i in range(len(dates)):
            if dates[i] == '':
                dates[i] = dates[i - 1]

        try:
            # opens next page
            page_buttons = driver.find_element_by_link_text('Next page').click()
        except:
            data = {
                "date": dates,
                "publisher": publishers,
                "title": titles,
                "content": content
            }
            
    # Closing the window
    driver.close()
    driver.quit()
    
    print(f'Scraper parsed {len(dates)} rows of content')
    
except:
    print('Scraper crashed for some reason')
# Out:
# Scraper parsed 2500 rows of content

# %%
 # -------------------- end timer -------------------- #
endTime = time.time()
totalTime = endTime - startTime
print(f"Total time required to complete parsing: {round(totalTime, 2)} seconds\n")
# Out:
# Total time required to complete parsing: 242.83 seconds

# %%
 # -------------------- Printing results -------------------- #
# print(f'\nPreview of publishers: {publishers}')
# print(f'Number of parsed publishers: {int(len(publishers))}')

# print(f'\nPreview of titles: {titles}')
# print(f'Number of parsed titles: {int(len(titles))}')

# print(f'\nPreview of content: {content}')
# print(f'Number of parsed content: {int(len(content))}')

# print(f'\nPreview of dates: {dates}')
# print(f'Number of parsed dates: {int(len(dates))}')

# %%
 # -------------------- Adding results to dictionary -------------------- #
data = {
    "date": dates,
    "publisher": publishers,
    "title": titles,
    "content": content
}

# %%
# -------------------- Saving data to a JSON file -------------------- #
# Serializing json
json_object = json.dumps(data, indent=4)

# Writing to sample.json
with open("FT_data_from_"+str(NUMBER_OF_PAGES)+"_pages.json", "w") as outfile:
    outfile.write(json_object)

# %%
print(f'''
number of dates: {len(data['date'])}
number of publishers: {len(data['publisher'])}
number of titles: {len(data['title'])}
number of content: {len(data['content'])}
''')

if len(data['title']) == len(data['content']) == len(data['publisher']) == len(data['date']):
    print('Arrays are the same length. Dataframe can be created.')
else:
    print('''
    Length is not equal. Dataframe cannot be created. 
    ''')
# Out:
# number of dates: 2500
# number of publishers: 2500
# number of titles: 2500
# number of content: 2500
#
# Arrays are the same length. Dataframe can be created.

# %%
# -------------------- Creating a DataFrame Object -------------------- #
my_df = pd.DataFrame(data, index=range(1, len(data['publisher'])+1))
my_df.tail()

# just to test if it works properly
# Out:
#                  date                       publisher  \
# 2496  JANUARY 22 2022          News in-depthSenseTime
# 2497  JANUARY 21 2022                         #techFT
# 2498  JANUARY 21 2022                    The Big Read
# 2499  JANUARY 21 2022  The FT ViewThe editorial board
# 2500  JANUARY 21 2022                  LexNetflix Inc
#
#                                                   title  \
# 2496  China’s SenseTime ponders future after US blac...
# 2497                    Investors stream out of Netflix
# 2498        Why gaming is the new Big Tech battleground
# 2499                    A much-needed market correction
# 2500           Netflix: don’t tune out just yet Premium
#
#                                                 content
# 2496  Xu Li has pulled off an IPO despite accusation...
# 2497  DeepMind co-founder quits, Intel picks Ohio, c...
# 2498  Microsoft’s $75bn purchase of Activision could...
# 2499  Sell-off led by technology stocks may reflect ...
# 2500  The focus on subscriber growth ignores the fac...

# %% [markdown]
# ### Reading our generated JSON file

# %%
# -------------------- Loading our generated JSON -------------------- #
my_df = pd.read_json('FT_data_from_'+str(NUMBER_OF_PAGES)+'_pages.json')
my_df.head()
# Out:
#         date                       publisher  \
# 0 2022-11-25              US-China relations
# 1 2022-11-25  The FT ViewThe editorial board
# 2 2022-11-25                    LexTesla Inc
# 3 2022-11-25            UK politics & policy
# 4 2022-11-25                     Stuart Kirk
#
#                                                title  \
# 0  Chinese telecoms groups Huawei and ZTE barred ...
# 1         How to make Britain a bigger force in tech
# 2  Tesla/China: recalls draw attention at a risky...
# 3  UK limits use of Chinese-made surveillance sys...
# 4      Stock investors needn’t lose sleep over rates
#
#                                              content
# 0  Washington cites national security in order th...
# 1  The UK cannot create the next Silicon Valley b...
# 2  Electric carmaker is far too invested in China...
# 3  Decision taken on security grounds following M...
# 4  Our columnist has bought into US equities and ...

# %%
my_df.shape
# Out:
# (2500, 4)

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2500 non-null   datetime64[ns]
#  1   publisher  2500 non-null   object
#  2   title      2500 non-null   object
#  3   content    2500 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 78.2+ KB

# %%
my_df[my_df['content'] == "NO CONTENT" ]
# Out:
#            date                                          publisher  \
# 11   2022-11-24                                       FT live news
# 12   2022-11-23                                       FT live news
# 43   2022-11-22                                       FT live news
# 58   2022-11-21                                       FT live news
# 114  2022-11-15                                       FT live news
# 125  2022-11-14                                       FT live news
# 128  2022-11-14                                     LexAveva Group
# 181  2022-11-08                                       FT live news
# 200  2022-11-07                                       FT live news
# 245  2022-11-01                                       FT live news
# 253  2022-10-31                                       FT live news
# 314  2022-10-25                                       FT live news
# 326  2022-10-24                                       FT live news
# 340  2022-10-20  US chip curbs start to bite and India explores...
# 351  2022-10-19                                       FT live news
# 364  2022-10-18                               LexTechnology sector
# 367  2022-10-18                                       FT live news
# 418  2022-10-11                                       FT live news
# 430  2022-10-10                                       FT live news
# 482  2022-10-04                                       FT live news
# 494  2022-10-03                                       FT live news
# 511  2022-09-29  China’s military companies seek new backers an...
# 699  2022-08-31                                         Collecting
# 700  2022-08-31                                       FT live news
# 708  2022-08-30                                       FT live news
# 759  2022-08-23                                       FT live news
# 805  2022-08-16                                       FT live news
# 813  2022-08-15                                       FT live news
# 829  2022-08-11                                 Streaming services
# 855  2022-08-09                                       FT live news
# 865  2022-08-08                                       FT live news
# 910  2022-08-01                                       FT live news
# 959  2022-07-26                                       FT live news
# 967  2022-07-25                                       FT live news
# 1015 2022-07-19                                       FT live news
# 1061 2022-07-13                                       FT live news
# 1119 2022-07-05                                       FT live news
# 1164 2022-06-28                                       FT live news
# 1447 2022-05-23  Government faces High Court trial over £854mn ...
# 1482 2022-05-18                          Why don’t computers work?
# 1577 2022-05-09                                       FT live news
# 1605 2022-05-05  Russian forces usurp Ukrainian internet infras...
# 1765 2022-04-19                                       FT live news
# 2214 2022-02-16    Chinese state pumps money into metaverse stakes
# 2367 2022-02-02  EU to outline tech standards plan to counter C...
# 2393 2022-01-31                                       FT live news
# 2436 2022-01-28                                       FT live news
#
#                                                   title     content
# 11    Live news updates from November 24: Hopes rise...  NO CONTENT
df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2453 entries, 0 to 2499
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2453 non-null   datetime64[ns]
#  1   publisher  2453 non-null   object
#  2   title      2453 non-null   object
#  3   content    2453 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 160.4+ KB
# None

# %%
my_df.head(20)
# Out:
#          date                               publisher  \
# 0  2022-11-25                      US-China relations
# 1  2022-11-25          The FT ViewThe editorial board
# 2  2022-11-25                            LexTesla Inc
# 3  2022-11-25                    UK politics & policy
# 4  2022-11-25                             Stuart Kirk
# 5  2022-11-24                   UK business & economy
# 6  2022-11-24                       Electric vehicles
# 7  2022-11-24                               #techAsia
# 8  2022-11-24                          Special Report
# 9  2022-11-24                    US midterm elections
# 10 2022-11-24  Special ReportNext Tech Growth Markets
# 13 2022-11-23                            LexJune Yoon
# 14 2022-11-23                          Pekka Lundmark
# 15 2022-11-23                               Apple Inc
# 16 2022-11-23                UnhedgedRobert Armstrong
# 17 2022-11-23                           Due Diligence
# 18 2022-11-23                            The Big Read
# 19 2022-11-23  Special ReportNext Tech Growth Markets
# 20 2022-11-23  Special ReportNext Tech Growth Markets
# 21 2022-11-23                          Special Report
#
#                                                 title  \
# 0   Chinese telecoms groups Huawei and ZTE barred ...
# 1          How to make Britain a bigger force in tech
# 2   Tesla/China: recalls draw attention at a risky...
# 3   UK limits use of Chinese-made surveillance sys...
# 4       Stock investors needn’t lose sleep over rates
# 5   Small businesses that tapped UK Covid loans fa...
# 6   Arrival’s founder to step down as chief of ele...
# 7   JD.com’s pay cuts and LG’s US battery bet Premium
# 8                            Next Tech Growth Markets
# 9   How #electiontwitter took over the political p...
# 10            Video games industry looks to the cloud
# 13  The Lex Newsletter: China will soothe zero-Cov...
# 14  The real future of the metaverse is not for co...
# 15  Apple iPhone factory workers clash with police...
# 16                           Is Disney cheap? Premium
# 17               Regrets from a Spac disaster Premium
# 18  How retailers are reshaping the advertising in...
# 19                  Advertisers binge on online video
# 20  Telecoms operators face anxious wait for 5G to...
# 21                                    Thriving Cities
#
#                                               content
# 0   Washington cites national security in order th...
# 1   The UK cannot create the next Silicon Valley b...
# 2   Electric carmaker is far too invested in China...
# 3   Decision taken on security grounds following M...
# 4   Our columnist has bought into US equities and ...
# 5   Anti-corruption campaigners seek release of ba...
# 6   Denis Sverdlov will be replaced by former head...
# 7   The inside story on the Asia tech trends that ...
# 8   The FT-Omdia Digital Economies Index highlight...
# 9   A clutch of amateur polling enthusiasts has ga...
# 10  Streaming services promise to make every devic...
# 13  Relaxation of curbs on film and gaming compani...
# 14  The creation of virtual reality ‘digital twins...
# 15  Violence erupts at Foxconn plant in Zhengzhou ...
# 16  Cable TV was a great business; streaming may n...
# 17  Plus, the FTX bankruptcy hearing kicks off in ...
# 18  They’re barely noticeable, but promoted items ...
# 19  TV and film companies are racing to capture so...
# 20  Consumers may be wowed by the next generation ...
# 21  This new series will track and highlight the m...

# %%
my_df.shape
# Out:
# (2453, 4)
